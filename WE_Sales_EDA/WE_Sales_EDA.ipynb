# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests
from datetime import datetime
import time
from dotenv import load_dotenv
import os
print('All necessary libraries as installed!')
# Out:
# All necessary libraries as installed!

# %%
# Configure visualizations

# %matplotlib inline
sns.set(style="whitegrid")
print('viz configured!')
# Out:
# viz configured!

# %%
# Load .env file
load_dotenv()

# Access Square API Token
ACCESS_TOKEN = os.getenv("SQUARE_ACCESS_TOKEN")
if not ACCESS_TOKEN:
    raise ValueError("Square API TOKEN not found in .env file!")

PAYMENTS_API_URL = 'https://connect.squareup.com/v2/payments'
ORDERS_API_URL = 'https://connect.squareup.com/v2/orders'
headers = {
    "Authorization": f"Bearer {ACCESS_TOKEN}",
    "Content-Type": "application/json"
}

# %%
def fetch_payment_data(start_date, end_date):
    response = requests.get(
        PAYMENTS_API_URL,
        headers=headers,
        params={
            "begin_time": f"{start_date}T00:00:00Z",
            "end_time": f"{end_date}T23:59:59Z"
        }
    )
    if response.status_code == 200:
        return pd.json_normalize(response.json().get("payments", []))
    else:
        print(f"Error: {response.status_code} - {response.text}")
        return pd.DataFrame()
    
start_date = "2024-01-01"
end_date = "2024-01-30"
payments_data = fetch_payment_data(start_date, end_date)

# %%
valid_payments = payments_data.dropna(subset=["order_id"])
def fetch_order_details(order_id):
    try:
        response = requests.get(f"{ORDERS_API_URL}/{order_id}", headers=headers)
        if response.status_code == 200:
            return response.json()
        else:
            print(f"Error fetching order {order_id}: {response.status_code} - {response.text}")
            return {}
    except Exception as e:
        print(f"Exception occured for order {order_id}: {e}")
        return {}

# %%
order_details = []
for order_id in payments_data['order_id']:
    order = fetch_order_details(order_id)
    if order:
        for item in order.get('line_items', []):
            order_details.append({
                "order_id": order_id,
                "item_name": item["name"],
                "quantity": item["quantity"],
                "gross_sales": item["gross_sales_money"]["amount"] / 100, 
                "category": item.get("category_name", "Unknown")
            })
    
    time.sleep(0.3)

# %%
order_df = pd.DataFrame(order_details)

if 'order_id' in payments_data.columns and 'order_id' in order_df.columns:
    enriched_data = pd.merge(payments_data, order_df, on="order_id", how="left")
else: 
    print("The 'order_id' column is missiong in one or more Dataframes.")
    enriched_data = payments_data

enriched_data.to_csv("enriched_data.csv", index=False)

print("Enriched data has been saved to 'enriched_data.csv'")

enriched_data_preview = pd.read_csv("enriched_data.csv")
enriched_data_preview.head()
# Out:
# The 'order_id' column is missiong in one or more Dataframes.
# Enriched data has been saved to 'enriched_data.csv'
#                             id                created_at  \
# 0  Ja9BICk5UrkN1NtDDaTtKEt6vaB  2024-01-30T20:52:21.389Z
# 1  lioAcYpgUBpVAXT3vv05cEUEuaB  2024-01-30T20:41:59.495Z
# 2  LF61s4rgmRCuPMwGOQAdGR5FvaB  2024-01-30T20:27:34.039Z
# 3  bV8Y8P5HS8HPDl21b138PHpcuaB  2024-01-30T20:16:21.575Z
# 4  VoPyRkACtYEvOE8syW5ZXpBSuaB  2024-01-30T20:13:27.845Z
#
#                  updated_at     status source_type    location_id  \
# 0  2024-01-30T20:52:29.932Z  COMPLETED        CARD  LW76KW1EJ9K7N
# 1  2024-01-30T20:42:01.100Z  COMPLETED        CASH  LW76KW1EJ9K7N
# 2  2024-01-30T20:27:35.551Z  COMPLETED        CASH  LW76KW1EJ9K7N
# 3  2024-01-30T20:16:30.869Z  COMPLETED        CARD  LW76KW1EJ9K7N
# 4  2024-01-30T20:13:36.560Z  COMPLETED        CARD  LW76KW1EJ9K7N
#
#                     order_id  \
# 0  llWLPuv4Qf4zeHEh2XmSmr0eV
# 1  1h8559Rphx3c3GhsWLQtJcfeV
# 2  HARIObYtxyvw80puKOfrjK9eV
# 3  RVtymxI9W9vYOAC331gNykteV
# 4  jOVCuhWg0GvTATmlRpbi7FgeV
#
#                                       processing_fee  \
# 0  [{'effective_at': '2024-01-30T22:52:29.000Z', ...
# 1                                                NaN
# 2                                                NaN
# 3  [{'effective_at': '2024-01-30T22:16:27.000Z', ...
# 4  [{'effective_at': '2024-01-30T22:13:35.000Z', ...
#
#                   customer_id       employee_id  ... buyer_email_address  \
# 0  ZCY835P01S5WDBD793RPR55H7R  TMSV3D5FpfPCwBUa  ...                 NaN
# 1                         NaN  TMSV3D5FpfPCwBUa  ...                 NaN
# 2                         NaN  TMSV3D5FpfPCwBUa  ...                 NaN
# 3  T3MCC6W38S5H542409G4SC5A94  TMSV3D5FpfPCwBUa  ...                 NaN
# 4  42H7MZZBSMJFFXB2K8PKSAS2QC  TMSV3D5FpfPCwBUa  ...                 NaN
#
#   delay_action delayed_until risk_evaluation.created_at  \
# 0          NaN           NaN                        NaN
# 1          NaN           NaN                        NaN
# 2          NaN           NaN                        NaN
# 3          NaN           NaN                        NaN
# 4          NaN           NaN                        NaN
#
#    risk_evaluation.risk_level shipping_address.first_name  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#    shipping_address.last_name application_details.application_id  \
# 0                         NaN                                NaN
# 1                         NaN                                NaN
# 2                         NaN                                NaN
# 3                         NaN                                NaN
# 4                         NaN                                NaN
#
#   billing_address.postal_code billing_address.country
# 0                         NaN                     NaN
# 1                         NaN                     NaN
# 2                         NaN                     NaN
# 3                         NaN                     NaN
# 4                         NaN                     NaN
#
# [5 rows x 69 columns]

# %%
enriched_data_preview.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 69 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   id                                                    100 non-null    object
#  1   created_at                                            100 non-null    object
#  2   updated_at                                            100 non-null    object
#  3   status                                                100 non-null    object
#  4   source_type                                           100 non-null    object
#  5   location_id                                           100 non-null    object
#  6   order_id                                              100 non-null    object
#  7   processing_fee                                        71 non-null     object
#  8   customer_id                                           74 non-null     object
#  9   employee_id                                           97 non-null     object
#  10  receipt_number                                        100 non-null    object
#  11  receipt_url                                           100 non-null    object
#  12  team_member_id                                        97 non-null     object
#  13  version_token                                         100 non-null    object
#  14  amount_money.amount                                   100 non-null    int64
#  15  amount_money.currency                                 100 non-null    object
#  16  tip_money.amount                                      52 non-null     float64
#  17  tip_money.currency                                    52 non-null     object
#  18  card_details.status                                   74 non-null     object
#  19  card_details.card.card_brand                          74 non-null     object
#  20  card_details.card.last_4                              74 non-null     float64
#  21  card_details.card.exp_month                           74 non-null     float64
#  22  card_details.card.exp_year                            74 non-null     float64
#  23  card_details.card.fingerprint                         74 non-null     object
#  24  card_details.card.card_type                           74 non-null     object
#  25  card_details.card.prepaid_type                        74 non-null     object
#  26  card_details.card.bin                                 74 non-null     float64
#  27  card_details.card.payment_account_reference           62 non-null     object
#  28  card_details.entry_method                             74 non-null     object
#  29  card_details.cvv_status                               71 non-null     object
#  30  card_details.avs_status                               71 non-null     object
#  31  card_details.auth_result_code                         74 non-null     object
#  32  card_details.application_identifier                   70 non-null     object
#  33  card_details.application_name                         70 non-null     object
#  34  card_details.application_cryptogram                   70 non-null     object
#  35  card_details.verification_method                      70 non-null     object
#  36  card_details.verification_results                     70 non-null     object
#  37  card_details.statement_description                    71 non-null     object
#  38  card_details.device_details.device_id                 72 non-null     object
#  39  card_details.device_details.device_name               0 non-null      float64
#  40  card_details.device_details.device_installation_id    72 non-null     object
#  41  card_details.card_payment_timeline.authorized_at      74 non-null     object
#  42  card_details.card_payment_timeline.captured_at        74 non-null     object
#  43  total_money.amount                                    100 non-null    int64
#  44  total_money.currency                                  100 non-null    object
#  45  approved_money.amount                                 74 non-null     float64
#  46  approved_money.currency                               74 non-null     object
#  47  device_details.device_id                              98 non-null     object
#  48  device_details.device_name                            0 non-null      float64
#  49  device_details.device_installation_id                 98 non-null     object
#  50  application_details.square_product                    100 non-null    object
#  51  cash_details.buyer_supplied_money.amount              26 non-null     float64
#  52  cash_details.buyer_supplied_money.currency            26 non-null     object
#  53  cash_details.change_back_money.amount                 26 non-null     float64
#  54  cash_details.change_back_money.currency               26 non-null     object
#  55  card_details.emv_details.authorization_response_code  55 non-null     float64
#  56  card_details.card.cardholder_name                     44 non-null     object
#  57  delay_duration                                        2 non-null      object
#  58  reference_id                                          2 non-null      float64
#  59  buyer_email_address                                   2 non-null      object
#  60  delay_action                                          2 non-null      object
#  61  delayed_until                                         2 non-null      object
#  62  risk_evaluation.created_at                            2 non-null      object
#  63  risk_evaluation.risk_level                            2 non-null      object
#  64  shipping_address.first_name                           2 non-null      object
#  65  shipping_address.last_name                            2 non-null      object
#  66  application_details.application_id                    2 non-null      object
#  67  billing_address.postal_code                           1 non-null      float64
#  68  billing_address.country                               1 non-null      object
# dtypes: float64(13), int64(2), object(54)
# memory usage: 54.0+ KB
